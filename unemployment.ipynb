# %%
import pandas as pd
import numpy as np
import altair as alt

# %%
def loaddata(filename, rateType):
    cur_filepath = filename
    data = pd.read_csv(cur_filepath)
    df = data.melt(var_name='Year',value_name='Unemployment rate(x1000)')
    df['Rate type'] = rateType
    return df

# %%
unemploy_df = loaddata("unemployment.csv", "All population")
unemploy_df_metro = loaddata("unemployment_metro.csv", "Metropolitanagglomeration")
unemploy_df_nonmetro = loaddata("unemployment_Nonmetro.csv", "Non-metropolitan/non-agglomeration")
unemploy_df = pd.concat([unemploy_df,unemploy_df_metro,unemploy_df_nonmetro])

# %%
alt.Chart(unemploy_df).mark_line(
    point=alt.OverlayMarkDef(color="blue")
).encode(
    x='Year',
    y='Unemployment rate(x1000)',
    color = alt.Color('Rate type', legend=alt.Legend(
        orient='none',
        legendX=-10, legendY=-40,
        direction='horizontal',
        titleAnchor='middle',titleLimit=1000)),
    tooltip=['Unemployment rate(x1000)','Rate type']
).properties(width=400, height=300).configure_legend(labelLimit= 0)
# Out:
# alt.Chart(...)

# %%
unemploy_df[(unemploy_df['Year'].astype(int) >= 2012) & (unemploy_df['Year'].astype(int) <= 2018)]
# Out:
#    Year  Unemployment rate(x1000)
# 1  2012                       7.3
# 2  2013                       7.1
# 3  2014                       6.9
# 4  2015                       6.9
# 5  2016                       7.1
# 6  2017                       6.4
# 7  2018                       5.9

# %%
unemploy_df
# Out:
#     Year  Unemployment rate(x1000)  \
# 0   2011                       7.6
# 1   2012                       7.3
# 2   2013                       7.1
# 3   2014                       6.9
# 4   2015                       6.9
# 5   2016                       7.1
# 6   2017                       6.4
# 7   2018                       5.9
# 8   2019                       5.7
# 9   2020                       9.5
# 10  2021                       7.5
# 0   2011                       7.5
# 1   2012                       7.3
# 2   2013                       7.0
# 3   2014                       6.9
# 4   2015                       6.8
# 5   2016                       7.0
# 6   2017                       6.3
# 7   2018                       5.8
# 8   2019                       5.7
# 9   2020                       9.7
# 10  2021                       7.5
# 0   2011                       7.5
# 1   2012                       7.3
# 2   2013                       7.0
# 3   2014                       6.9
# 4   2015                       6.8
# 5   2016                       7.0
# 6   2017                       6.3
# 7   2018                       5.8
# 8   2019                       5.7
# 9   2020                       9.7
# 10  2021                       7.5
#
#                                       Rate type
# 0                                All population
# 1                                All population
# 2                                All population
# 3                                All population
# 4                                All population
# 5                                All population
# 6                                All population
# 7                                All population
# 8                                All population
# 9                                All population
# 10                               All population
# 0           Metropolitan area and agglomeration
# 1           Metropolitan area and agglomeration
# 2           Metropolitan area and agglomeration
# 3           Metropolitan area and agglomeration
# 4           Metropolitan area and agglomeration
# 5           Metropolitan area and agglomeration
# 6           Metropolitan area and agglomeration
# 7           Metropolitan area and agglomeration
# 8           Metropolitan area and agglomeration
# 9           Metropolitan area and agglomeration
# 10          Metropolitan area and agglomeration
# 0   Non-metropolitan area and non-agglomeration
# 1   Non-metropolitan area and non-agglomeration
# 2   Non-metropolitan area and non-agglomeration
# 3   Non-metropolitan area and non-agglomeration
# 4   Non-metropolitan area and non-agglomeration
# 5   Non-metropolitan area and non-agglomeration
# 6   Non-metropolitan area and non-agglomeration
# 7   Non-metropolitan area and non-agglomeration
# 8   Non-metropolitan area and non-agglomeration
# 9   Non-metropolitan area and non-agglomeration
# 10  Non-metropolitan area and non-agglomeration
